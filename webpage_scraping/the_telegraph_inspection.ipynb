# %%
# The Telegraph Url

import requests

URL = 'https://www.telegraph.co.uk/'
page = requests.get(URL)

# %%
# Parse the content

from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="homePageRendererHTML no-js" lang="en-GB" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
# <title>The Telegraph - Telegraph Online, Daily Telegraph, Sunday Telegraph - Telegraph</title>
# <link href="//cdn.polyfill.io" rel="dns-prefetch"/>
# <link href="//static.telegraph.co.uk" rel="dns-prefetch"/>
# <link href="//assets.adobedtm.com" rel="dns-prefetch"/>
# <link href="//d3c3cq33003psk.cloudfront.net" rel="dns-prefetch"/>
# <link href="//c.evidon.com" rel="dns-prefetch"/>
# <link href="//cdn.petametrics.com" rel="dns-prefetch"/>
# <link href="//telegraphmedia.bootstrap.fyre.co" rel="dns-prefetch"/>
# <link as="font" crossorigin="crossorigin" href="/etc/designs/telegraph/core/clientlibs/ui/dist/static/fonts/Austin-News-Deck-Web-Semibold.woff2" rel="preload" type="font/woff2"/>
# <link href="/etc/designs/telegraph/core/clientlibs/core/icons/favicon.ico" rel="shortcut icon"/>
# <link href="/etc/designs/telegraph/core/clientlibs/core/icons/favicon-152x152.png" rel="icon" sizes="152x152" type="image/png"/>
# <link href="/etc/designs/telegraph/core/clientlibs/core/icons/favicon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <meta content="#2c769d" name="msapplication-TileColor"/>
# <meta content="/etc/designs/telegraph/core/clientlibs/core/icons/mstile-144x144.png" name="msapplication-TileImage"/>
# <!--/* IE 11 Tile for Windows 8.1 Start Screen */ -->
# <meta content="The Telegraph" name="msapplication-tooltip"/>
# <meta content="/etc/designs/telegraph/core/clientlibs/core/icons/browserconfig.xml" name="msapplication-config"/>
# <meta content="/etc/designs/telegraph/core/clientlibs/core/icons/mstile-310x310.png" name="msapplication-square310x310logo"/>
# <meta content="/etc/designs/telegraph/core/clientlibs/core/icons/mstile-310x150.png" name="msapplication-wide310x150logo"/>
# <meta content="/etc/designs/telegraph/core/clientlibs/core/icons/mstile-150x150.png" name="msapplication-square150x150logo"/>
# <meta content="/etc/designs/telegraph/core/clientlibs/core/icons/mstile-70x70.png" name="msapplication-square70x70logo"/>
# <script data-pagespeed-no-defer="">//<![CDATA[
# (function(){function d(b){var a=window;if(a.addEventListener)a.addEventListener("load",b,!1);else if(a.attachEvent)a.attachEvent("onload",b);else{var c=a.onload;a.onload=function(){b.call(this);c&&c.call(this)}}}var p=Date.now||function(){return+new Date};window.pagespeed=window.pagespeed||{};var q=window.pagespeed;function r(){this.a=!0}r.prototype.c=function(b){b=parseInt(b.substring(0,b.indexOf(" ")),10);return!isNaN(b)&&b<=p()};r.prototype.hasExpired=r.prototype.c;r.prototype.b=function(b){return b.substring(b.indexOf(" ",b.indexOf(" ")+1)+1)};r.prototype.getData=r.prototype.b;r.prototype.f=function(b){var a=document.getElementsByTagName("script"),a=a[a.length-1];a.parentNode.replaceChild(b,a)};r.prototype.replaceLastScript=r.prototype.f;
# r.prototype.g=function(b){var a=window.localStorage.getItem("pagespeed_lsc_url:"+b),c=document.createElement(a?"style":"link");a&&!this.c(a)?(c.type="text/css",c.appendChild(document.createTextNode(this.b(a)))):(c.rel="stylesheet",c.href=b,this.a=!0);this.f(c)};r.prototype.inlineCss=r.prototype.g;
# r.prototype.h=function(b,a){var c=window.localStorage.getItem("pagespeed_lsc_url:"+b+" pagespeed_lsc_hash:"+a),f=document.createElement("img");c&&!this.c(c)?f.src=this.b(c):(f.src=b,this.a=!0);for(var c=2,k=arguments.length;c<k;++c){var g=arguments[c].indexOf("=");f.setAttribute(arguments[c].substring(0,g),arguments[c].substring(g+1))}this.f(f)};r.prototype.inlineImg=r.prototype.h;
# function t(b,a,c,f){a=document.getElementsByTagName(a);for(var k=0,g=a.length;k<g;++k){var e=a[k],m=e.getAttribute("data-pagespeed-lsc-hash"),h=e.getAttribute("data-pagespeed-lsc-url");if(m&&h){h="pagespeed_lsc_url:"+h;c&&(h+=" pagespeed_lsc_hash:"+m);var l=e.getAttribute("data-pagespeed-lsc-expiry"),l=l?(new Date(l)).getTime():"",e=f(e);if(!e){var n=window.localStorage.getItem(h);n&&(e=b.b(n))}e&&(window.localStorage.setItem(h,l+" "+m+" "+e),b.a=!0)}}}
# function u(b){t(b,"img",!0,function(a){return a.src});t(b,"style",!1,function(a){return a.firstChild?a.firstChild.nodeValue:null})}
# q.i=function(){if(window.localStorage){var b=new r;q.localStorageCache=b;d(function(){u(b)});d(function(){if(b.a){for(var a=[],c=[],f=0,k=p(),g=0,e=window.localStorage.length;g<e;++g){var m=window.localStorage.key(g);if(!m.indexOf("pagespeed_lsc_url:")){var h=window.localStorage.getItem(m),l=h.indexOf(" "),n=parseInt(h.substring(0,l),10);if(!isNaN(n))if(n<=k){a.push(m);continue}else if(n<f||!f)f=n;c.push(h.substring(l+1,h.indexOf(" ",l+1)))}}k="";f&&(k="; expires="+(new Date(f)).toUTCString());document.cookie=
# "_GPSLSC="+c.join("!")+k;g=0;for(e=a.length;g<e;++g)window.localStorage.removeItem(a[g]);b.a=!1}})}};q.localStorageCacheInit=q.i;})();
# pagespeed.localStorageCacheInit();
# //]]></script><link href="/etc/designs/telegraph/core/clientlibs/ui.min.5-49--2.css" rel="stylesheet" type="text/css"/><style data-pagespeed-lsc-expiry="Thu, 14 Jan 2021 09:00:07 GMT" data-pagespeed-lsc-hash="AqXZrgyRJZ" data-pagespeed-lsc-url="https://www.telegraph.co.uk/etc/designs/telegraph/core/clientlibs/uifooterlegacy.min.5-49--2.css">.snippet-footer{color:#666;font-size:1.2rem;line-height:2.4rem}.footer-list-corporate__list{border-top:1px solid #c9c9c9;display:flex;flex-direction:column;flex-wrap:wrap;list-style:none;padding:8px 0}@media only screen and (min-width:768px){.footer-list-corporate__list{flex-direction:row}}.footer-copyright{margin:10px 0 40px}.footer-copyright p{font-size:12px}.footer-list-corporate__link{color:#666;padding-right:10px;text-decoration:none}</style><script>!function(l){function h(c){for(var d,n,k=c[0],b=c[1],m=c[2],q=0,r=[];q<k.length;q++)n=k[q],p[n]&&r.push(p[n][0]),p[n]=0;for(d in b)Object.prototype.hasOwnProperty.call(b,d)&&(l[d]=b[d]);for(a&&a(c);r.length;)r.shift()();return e.push.apply(e,m||[]),f()}function f(){for(var c,a=0;a<e.length;a++){for(var n=e[a],k=!0,m=1;m<n.length;m++)0!==p[n[m]]&&(k=!1);k&&(e.splice(a--,1),c=b(b.s=n[0]))}return c}function b(a){if(g[a])return g[a].exports;var c=g[a]={i:a,l:!1,exports:{}};return l[a].call(c.exports,c,c.exports,b),c.l=!0,c.exports}var g={},p={1:0},e=[];b.m=l;b.c=g;b.d=function(a,d,n){b.o(a,d)||Object.defineProperty(a,d,{enumerable:!0,get:n})};b.r=function(a){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(a,Symbol.toStringTag,{value:"Module"});Object.defineProperty(a,"__esModule",{value:!0})};b.t=function(a,d){if((1&d&&(a=b(a)),8&d)||4&d&&"object"==typeof a&&a&&a.__esModule)return a;var c=Object.create(null);if(b.r(c),Object.defineProperty(c,"default",{enumerable:!0,value:a}),2&d&&"string"!=typeof a)for(var k in a)b.d(c,k,function(c){return a[c]}.bind(null,k));return c};b.n=function(a){var c=a&&a.__esModule?function(){return a.default}:function(){return a};return b.d(c,"a",c),c};b.o=function(a,d){return Object.prototype.hasOwnProperty.call(a,d)};b.p="";var q=window["tmg.build"]=window["tmg.build"]||[],r=q.push.bind(q);q.push=h;q=q.slice();for(var m=0;m<q.length;m++)h(q[m]);var a=r;f()}([]);(window["tmg.build"]=window["tmg.build"]||[]).push([[0],{0:function(l,h,f){var b,g;f=[h];void 0===(g="function"==typeof(b=function(b){Object.defineProperty(b,"__esModule",{value:!0});window.tmg=window.tmg||{};var e=function(b){try{var e=tmg,m=b.split(".");return"tmg"===m[0]&&(m=m.slice(1)),m.forEach(function(a){void 0===e[a]&&(e[a]={});e=e[a]}),e}catch(a){console.warn("couldn't create namespace:",b)}};window.tmg.createNamespace=e;b.default={create:e}})?b.apply(h,f):b)||(l.exports=g)},1:function(l,h,f){var b,g;f=[h,f(0)];void 0===(g="function"==typeof(b=function(b,e){Object.defineProperty(b,"__esModule",{value:!0});e=e&&e.__esModule?e:{default:e};var f=function(){function b(a,c){for(var d=0;d<c.length;d++){var b=c[d];b.enumerable=b.enumerable||!1;b.configurable=!0;"value"in b&&(b.writable=!0);Object.defineProperty(a,b.key,b)}}return function(a,c,d){return c&&b(a.prototype,c),d&&b(a,d),a}}(),p=new (function(){function b(){if(!(this instanceof b))throw new TypeError("Cannot call a class as a function");!0;this.topics=[];this.publishedTopics=[];this.UID=-1}return f(b,[{key:"subscribe",value:function(a){var c=a.topic,d=a.func;if("function"!=typeof d)return!1;if(a.runIfAlreadyPublished)for(a=0;a<this.publishedTopics.length;a++)this.publishedTopics[a]===c&&d.call();a=(this.UID+=1).toString();return this.topics.push({token:a,topic:c,func:d}),a}},{key:"unsubscribe",value:function(a){a=a.topic;for(var c=0;c<this.topics.length;c++)this.topics[c].topic===a&&this.topics.splice(c,1)}},{key:"publish",value:function(a){a=a.topic;this.publishedTopics.push(a);for(var c=0;c<this.topics.length;c++)this.topics[c].topic===a&&this.topics[c].func.call()}}]),b}());e.default.create("tmg.pubsub");window.tmg.pubsub=p;b.default=p})?b.apply(h,f):b)||(l.exports=g)},15 ...
# <script>
# 	RUM.mark('css_load_ui');
# </script>
# <script defer="" src="https://cdn.polyfill.io/v3/polyfill.min.js?flags=gated&amp;features=default,fetch,IntersectionObserver,NodeList.prototype.forEach,Array.prototype.@@iterator&amp;Array.prototype.includes&amp;callback=tmg.polyfill.complete"></script>
# <script>
# 	RUM.mark( 'js_load_polyfill' );
# </script>
# <script defer="" src="/etc/designs/telegraph/core/clientlibs/ui.min.5-49--2.js"></script>
# <script>
# 	RUM.mark('js_load_ui');
# </script>
# <link href="https://www.telegraph.co.uk/" rel="canonical">
# <meta content="Latest news, business, sport, comment, lifestyle and culture from the Daily Telegraph and Sunday Telegraph newspapers and video from Telegraph TV." name="description"/>
# <meta name="keywords"/>
# <meta content="portal" name="tmgads.channel"/>
# <meta name="tmgads.section"/>
# <meta content="portal" name="tmgads.zone"/>
# <meta content="AlZ6LpQcLmsv" name="tmgads.articleid"/>
# <meta content="index" name="tmgads.pagetype"/>
# <meta content="0" name="tmgads.level"/>
# <meta name="tmgads.otherdata"/>
# <meta content="GB" name="tmgads.geo"/>
# <meta name="tmgads.keywords"/>
# <meta content="portal" name="DCSext.Channel"/>
# <meta name="DCSext.Category"/>
# <meta name="DCSext.Genre"/>
# <meta content="portal" name="DCSext.MLC"/>
# <meta content="AlZ6LpQcLmsv" name="DCSext.articleId"/>
# <meta content="index" name="DCSext.Content_Type"/>
# <meta content="0" name="DCSext.Level"/>
# <meta name="DCSext.author"/>
# <meta content="2014-11-14 13:05" name="DCSext.articleFirstPublished"/>
# <meta content="0" name="DCSext.cf"/>
# <meta content="0" name="DCSext.cd"/>
# <meta content="0" name="DCSext.cn"/>
# <meta content="1" name="DCSext.pd"/>
# <meta content="Telegraph" property="og:title"/>
# <meta content="Latest news, business, sport, comment, lifestyle and culture from the Daily Telegraph and Sunday Telegraph newspapers and video from Telegraph TV." property="og:description"/>
# <meta content="homepage" property="og:type"/>
# <meta content="The Telegraph" property="og:site_name"/>
# <meta content="https://www.telegraph.co.uk/" property="og:url"/>
# <meta property="og:image"/>
# <meta content="@Telegraph" name="twitter:title"/>
# <meta content="https://www.telegraph.co.uk/" name="twitter:url"/>
# <meta name="twitter:image"/>
# <meta content="@Telegraph" name="twitter:site"/>
# <meta content="Latest news, business, sport, comment, lifestyle and culture from the Daily Telegraph and Sunday Telegraph newspapers and video from Telegraph TV." name="twitter:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="portal" name="tmgads.businessSegment"/>
# <meta name="tmg.sponsor"/>
# <meta name="DCSext.campaignId"/>
# <meta name="DCSext.campaignStart"/>
# <meta name="DCSext.campaignEnd"/>
# <meta name="DCSext.sponsored"/>
# <meta content="false" name="tmg.premium.override"/>
# <meta content="false" name="tmg.premium.state"/>
# <meta content="false" name="premiumContentOnFirstPublish"/>
# <meta content="143666524748" property="fb:pages"/>
# <meta content="1438053159792450" property="fb:pages"/>
# <meta content="1069269459751990" property="fb:pages"/>
# <meta content="985629951556153" property="fb:pages"/>
# <meta content="121391718031592" property="fb:pages"/>
# <meta content="187451147952038" property="fb:pages"/>
# <meta content="244632882562393" property="fb:pages"/>
# <meta content="1443454839014980" property="fb:pages"/>
# <meta content="551022578388741" property="fb:pages"/>
# <meta content="534435549980003" property="fb:pages"/>
# <meta content="751195545009382" property="fb:pages"/>
# <meta content="116941904987458" property="fb:pages"/>
# <meta content="285329994977070" property="fb:pages"/>
# <meta content="122346694516955" property="fb:pages"/>
# <meta content="free" property="article:content_tier"/>
# <script>
# 	window.tmgFacebookAppId = "1785449471702494";
# </script>
# <script>
# 	var dataLayer = {
# 		pageName:'',
# 		pageType: 'homePageRenderer',
# 		pageId: 'AlZ6LpQcLmsv',
# 		conceptIds: '[]',
# 		rollupContentPath: 'portal',
# 		videoEmbedded: 'false',
# 		videoEmbedCount: '0',
# 		premiumContent: 'false',
# 		premiumOverride: ''
# 	};
# </script>
# <meta content="#072A3A" name="theme-color"/>
# <meta content="#072A3A" name="msapplication-navbutton-color"/>
# <script>
# 	var pageData = {};
# </script>
# <meta content="max-snippet:-1,max-image-preview:standard,max-video-preview:-1" name="robots"/>
# <script>
# 	var tmgAds = tmgAds || {};
# 	tmgAds.sticky = false;
# </script>
# <script defer="" src="//assets.adobedtm.com/71dcbb11123ce6b2e1ce4d47fd79a130aad3fc95/satelliteLib-177113f60f763788009998023cd15615fe2168a2.js"></script>
# <script>
# 	RUM.mark('js_load_dtm');
# </script>
# <script defer="" src="https://static.telegraph.co.uk/telegraph-advertising/tmg-gpt.min.js"></script>
# <script>
# 		RUM.mark( 'js_load_gpt' );
# 	</script>
# <script>
# 	window.tmgOoyala = {
# 		api: {
# 			pcode: 'RvbGU6Z74XE_a3bj4QwRGByhq9h2',
# 			playerBrandingId: 'ZTIxYmJjZDM2NWYzZDViZGRiOWJjYzc5'
# 		}
# 	};
# </script>
# <!-- MarTech (Target) -->
# <script defer="" src="https://www.telegraph.co.uk/martech/js/core.min.js"></script>
# <script defer="" src="//d3c3cq33003psk.cloudfront.net/opentag-35657-1096944.js"></script>
# <script>
# 	RUM.mark( 'js_load_opentag' );
# </script>
# <script>!function(){function o(n,i){if(n&&i)for(var r in i)i.hasOwnProperty(r)&&(void 0===n[r]?n[r]=i[r]:n[r].constructor===Object&&i[r].constructor===Object?o(n[r],i[r]):n[r]=i[r])}try{var n=decodeURIComponent("");if(n.length>0&&window.JSON&&"function"==typeof window.JSON.parse){var i=JSON.parse(n);void 0!==window.BOOMR_config?o(window.BOOMR_config,i):window.BOOMR_config=i}}catch(r){window.console&&"function"==typeof window.console.error&&console.error("mPulse: Could not parse configuration",r)}}();</script>
# <script>!function(e){var a="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,a="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="GHENT-R5DY7-KAG4V-6EY7K-3RGVU",function(){function n(a){e.BOOMR_onload=a&&a.timeStamp||(new Date).getTime()}if(!e.BOOMR||!e.BOOMR.version&&!e.BOOMR.snippetExecuted){e.BOOMR=e.BOOMR||{},e.BOOMR.snippetExecuted=!0;var i,o,r,_=document.createElement("iframe");if(e[t])e[t]("load",n,!1);else if(e.attachEvent)e.attachEvent("onload",n);_.src="javascript:void(0)",_.title="",_.role="presentation",(_.frameElement||_).style.cssText="width:0;height:0;border:0;display:none;",r=document.getElementsByTagName("script")[0],r.parentNode.insertBefore(_,r);try{o=_.contentWindow.document}catch(O){i=document.domain,_.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",o=_.contentWindow.document}o.open()._l=function(){var e=this.createElement("script");if(i)this.domain=i;e.id="boomr-if-as",e.src=a+"GHENT-R5DY7-KAG4V-6EY7K-3RGVU",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(e)},o.write("<bo"+'dy onload="document._l();">'),o.close()}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var a=""=="true"?1:0,t="",n="qdzqeddip4nxaxrb2zgq-f-85ead20c1-clientnsv4-s.akamaihd.net",i={"ak.v":25,"ak.cp":"44707","ak.ai":parseInt("148538",10),"ak.ol":"0","ak.cr":26,"ak.ipv":4,"ak.proto":"","ak.rid":"f36990af","ak.r":28110,"ak.a2":a,"ak.m":"j","ak.n":"essl","ak.bpcip":"128.243.2.0","ak.cport":62800,"ak.gh":"72.247.176.167","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1579275853"};if(""!==t)i["ak.ruds"]=t;var o={i:!1,av:function(a){var t="http.initiator";if(a&&(!a[t]||"spa_hard"===a[t]))i["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!o.i){var e=BOOMR.subscribe;e("before_beacon",o.av,null,null),e("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></link></head>
# <body class="theme theme--">
# <div class="advert js-advert js-advert-banner advert--banner advert--header" id="advert_tmg_ban"></div>
# <main class="container container--content" itemscope="" itemtype="https://schema.org/CollectionPage">
# <a aria-hidden="false" hidden="" href="#navigation">Jump to navigation</a>
# <div class="grid">
# <div class="grid-col grid-col-12">
# </div>
# <div class="grid-col grid-col-12 grid-col-md-8 grid packages">
# <section class="package grid-col grid-col-12 grid-col-sm-8 package--medium" data-test="package--medium">
# <h3 class="package__heading u-heading-8">top stories</h3>
# <div class="package__grid grid">
# <article class="card u-clickable-area grid-col grid-col-12 grid-col-sm-8 package-separator-bottom-xs package-separator-right-sm package-separator-high" data-test="card">
# <h3 class="list-headline u-heading-1" data-track-wrapper="0-top stories">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/politics/2020/01/17/exclusive-mps-500000-bill-sound-brexit-bongs-35-times-sounding/">
# <span class="list-headline__text">
# <span class="e-kicker u-separator-right--tight-inline">
# Exclusive
# </span>
# MPs' £500,000 bill to sound 'Brexit bongs' is 35 times more than sounding Big Ben on New Year's Eve
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/christopher-hope/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Christopher Hope" itemprop="name">Christopher Hope</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <article class="card u-clickable-area grid-col grid-col-12 grid-col-sm-4 package-separator-top-xs" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="0-top stories">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/politics/2020/01/17/eu-citizens-will-not-automatically-deported-brexit-grace-period/">
# <span class="list-headline__text">
# EU citizens will not be automatically deported after the Brexit grace period, says Guy Verhofstadt
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/harry-yorke/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Harry Yorke" itemprop="name">Harry Yorke</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <article class="card u-clickable-area grid-col grid-col-6 grid-col-sm-8 package-separator-top package-separator-right" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="0-top stories">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/rugby-union/2020/01/17/saracens-players-told-club-will-effectively-relegated-gallagher/">
# <span class="list-headline__text">
# Saracens players told relegation inevitable after club accepts another deduction
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/daniel-schofield/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Daniel Schofield" itemprop="name">Daniel Schofield</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <article class="card u-clickable-area grid-col grid-col-6 grid-col-sm-4 package-separator-top" data-test="card">
# <h3 class="list-headline u-heading-7" data-track-wrapper="0-top stories">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/news/2020/01/17/football-sale-agents-manager-sentenced-corruption-scandal/">
# <span class="list-headline__text">
# <span class="e-kicker u-separator-right--tight-inline">
# Football for sale
# </span>
# Agents and manager sentenced over corruption scandal
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/patrick-sawer/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Patrick Sawer" itemprop="name">Patrick Sawer</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# </div>
# </section>
# <section class="package grid-col grid-col-12 grid-col-sm-4 package--small" data-test="package--small">
# <h3 class="package__heading u-heading-8">Royal family</h3>
# <div class="package__grid grid">
# <article class="card u-clickable-area grid-col grid-col-12 package-separator-bottom" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-5" data-track-wrapper="1-Royal family">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/royal-family/2020/01/17/meghan-markle-joined-canadian-hideaway-little-blonde-guru-pilates/">
# <span class="list-headline__text">
# Meghan joined at her Canadian hideaway by 'little blonde guru' Pilates instructor
# </span>
# </a>
# </h3>
# <p class="e-standfirst e-standfirst--card" data-test="standfirst" itemprop="description">
# Heather Dorak was seen arriving at Vancouver airport, where she was picked up by the Duchess
# </p>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/olivia-rudgard/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Olivia Rudgard" itemprop="name">Olivia Rudgard</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <article class="card u-clickable-area grid-col grid-col-12" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="1-Royal family">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/health-fitness/body/heather-dorak-meghans-close-friend-pilates-teacher/">
# <span class="list-headline__text">
# Who is Heather Dorak, Meghan’s close friend and Pilates teacher?
# </span>
# </a>
# </h3>
# </article>
# </div>
# </section>
# <section class="package grid-col grid-col-12 package--large" data-test="package--large">
# <h3 class="package__heading u-heading-8">THIRD TEST</h3>
# <div class="package__grid grid">
# <article class="card u-clickable-area grid-col grid-col-12 grid-col-sm-4 package-separator-bottom" data-test="card">
# <h3 class="list-headline" data-track-wrapper="2-THIRD TEST">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/cricket/2020/01/17/south-africa-v-england-third-test-day-two-live-score-latest/">
# <span class="list-headline__text">
# <span class="label-live u-separator-right--tight">
# <span class="label-live__icon">
# <span class="label-live__icon-inner"></span>
# </span>
# <span class="label-live__copy">Live</span>
# </span>
# <span class="e-kicker u-separator-right--tight-inline">
# South Africa v England day two
# </span>
# Live score and latest updates
# </span>
# </a>
# </h3>
# <p class="e-standfirst e-standfirst--card" data-test="standfirst" itemprop="description">
# Stokes and Pope dominate as tourists build a big first innings score in Port Elizabeth
# </p>
# </article>
# <div class="grid-col grid-col-12 grid-col-sm-8 grid-row-lg-3 package__image package__image--large">
# <a href="/cricket/2020/01/17/south-africa-v-england-third-test-day-two-live-score-latest/">
# <figure class="package__figure">
# <div class="lazy-image package__image-src" data-alt="England's Ollie Pope salutes the crowd" data-class="lazy-image__img" data-js="LazyImage" data-sizes="(min-width: 768px) 640px, 100vw" data-src="/content/dam/cricket/2020/01/17/TELEMMGLPICT000221601947_trans_NvBQzQNjv4BqaYt6_6mhPFT1pgycbdaP49kJ3f7O4tq7HT1qEua8Nwc.jpeg" data-srcset="/content/dam/cricket/2020/01/17/TELEMMGLPICT000221601947_trans_NvBQzQNjv4BqaYt6_6mhPFT1pgycbdaP49kJ3f7O4tq7HT1qEua8Nwc.jpeg?imwidth=160 160w, /content/dam/cricket/2020/01/17/TELEMMGLPICT000221601947_trans_NvBQzQNjv4BqaYt6_6mhPFT1pgycbdaP49kJ3f7O4tq7HT1qEua8Nwc.jpeg?imwidth=210 210w, /content/dam/cricket/2020/01/17/TELEMMGLPICT000221601947_trans_NvBQzQNjv4BqaYt6_6mhPFT1pgycbdaP49kJ3f7O4tq7HT1qEua8Nwc.jpeg?imwidth=320 320w, /content/dam/cricket/2020/01/17/TELEMMGLPICT000221601947_trans_NvBQzQNjv4BqaYt6_6mhPFT1pgycbdaP49kJ3f7O4tq7HT1qEua8Nwc.jpeg?imwidth=350 350w, /content/dam/cricket/2020/01/17/TELEMMGLPICT000221601947_trans_NvBQzQNjv4BqaYt6_6mhPFT1pgycbdaP49kJ3f7O4tq7HT1qEua8Nwc.jpeg?imwidth=480 480w, /content/dam/cricket/2020/01/17/TELEMMGLPICT000221601947_trans_NvBQzQNjv4BqaYt6_6mhPFT1pgycbdaP49kJ3f7O4tq7HT1qEua8Nwc.jpeg?imwidth=640 640w" style="padding-top:62.5%;">
# <noscript>
# <img alt="England's Ollie Pope salutes the crowd" class="responsive lazy-image__img package__image-src" src="/content/dam/cricket/2020/01/17/TELEMMGLPICT000221601947_trans_NvBQzQNjv4BqaYt6_6mhPFT1pgycbdaP49kJ3f7O4tq7HT1qEua8Nwc.jpeg"/>
# </noscript>
# </div>
# </figure>
# </a>
# </div>
# <article class="card u-clickable-area grid-col grid-col-6 grid-col-sm-4 package-separator-top-right" data-test="card">
# <h3 class="list-headline u-heading-7" data-track-wrapper="2-THIRD TEST">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/cricket/2020/01/17/south-africa-hit-massive-blow-kagiso-rabada-banned-final-test/">
# <span class="list-headline__text">
# South Africa hit with massive blow as Rabada banned for final Test for wicket celebration
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/nick-hoult/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Nick Hoult" itemprop="name">Nick Hoult</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <article class="card u-clickable-area grid-col grid-col-6 grid-col-sm-8 grid-col-lg-4 package-separator-top-right card--not-fullwidth" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="2-THIRD TEST">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/cricket/2020/01/17/cricket-always-finds-way-shoot-foot-kagiso-rabada-ban-celebrating/">
# <span class="list-headline__text">
# Cricket always finds a way to shoot itself in the foot - the Kagiso Rabada ban for celebrating is ridiculous
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <a aria-label="Articles by Michael Vaughan" class="card__link" href="/authors/michael-vaughan/">
# <div class="lazy-image card__author-image card__author-image--s" data-alt="Michael Vaughan" data-class="lazy-image__img" data-js="LazyImage" data-src="/content/dam/Author%20photos/Michael_Vaughan1.png?impolicy=byline-author" style="padding-top:%;">
# <noscript>
# <img alt="Michael Vaughan" class="responsive lazy-image__img card__author-image card__author-image--s" src="/content/dam/Author%20photos/Michael_Vaughan1.png?impolicy=byline-author"/>
# </noscript>
# </div>
# </a>
# <div class="card__meta-wrapper">
# <span class="e-byline e-byline--opinion" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a aria-label="Articles by Michael Vaughan" class="e-byline__link" href="/authors/michael-vaughan/" rel="author">
# <span class="e-byline__author" content="Michael Vaughan" itemprop="name">Michael Vaughan</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# </div>
# </section>
# <div class="packages__advert grid-col grid-col-12 u-full-bleed">
# <div class="advert-label">Advertisement</div>
# <div class="advert js-advert" id="advert_tmg_mpu"></div>
# </div>
# <section class="package grid-col grid-col-12 grid-col-sm-4 package--small" data-test="package--small">
# <h3 class="package__heading u-heading-8">Money</h3>
# <div class="package__grid grid">
# <article class="card u-clickable-area grid-col grid-col-8" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-5" data-track-wrapper="3-Money">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/personal-banking/current-accounts/going-full-monzo-can-damage-credit-score/">
# <span class="list-headline__text">
# Why going 'full Monzo' can damage your credit score
# </span>
# </a>
# </h3>
# <p class="e-standfirst e-standfirst--card" data-test="standfirst" itemprop="description">
# Customers who 'go full Monzo' could end up with weaker credit scores, harming their ability to borrow
# </p>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/sam-barker/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Sam Barker" itemprop="name">Sam Barker</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <div class="grid-col grid-col-4 package__image">
# <a href="/personal-banking/current-accounts/going-full-monzo-can-damage-credit-score/">
# <figure class="package__figure">
# <div class="lazy-image package__image-src" data-class="lazy-image__img" data-js="LazyImage" data-sizes="(min-width: 768px) 160px, 33.333vw" data-src="/content/dam/PortalPictures/January2020/170120_MONZO-PL.jpg" data-srcset="/content/dam/PortalPictures/January2020/170120_MONZO-PL.jpg?imwidth=160 160w, /content/dam/PortalPictures/January2020/170120_MONZO-PL.jpg?imwidth=210 210w, /content/dam/PortalPictures/January2020/170120_MONZO-PL.jpg?imwidth=320 320w, /content/dam/PortalPictures/January2020/170120_MONZO-PL.jpg?imwidth=350 350w, /content/dam/PortalPictures/January2020/170120_MONZO-PL.jpg?imwidth=480 480w, /content/dam/PortalPictures/January2020/170120_MONZO-PL.jpg?imwidth=640 640w" style="padding-top:160%;">
# <noscript>
# <img class="responsive lazy-image__img package__image-src" src="/content/dam/PortalPictures/January2020/170120_MONZO-PL.jpg"/>
# </noscript>
# </div>
# </figure>
# </a>
# </div>
# <article class="card u-clickable-area grid-col grid-col-12 package-separator-top" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="3-Money">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/investing/shares/british-stock-returned-amazon-last-decade/">
# <span class="list-headline__text">
# The British stock that returned more than Amazon in the last decade
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/jonathan-jones/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Jonathan Jones" itemprop="name">Jonathan Jones</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# </div>
# </section>
# <section class="package grid-col grid-col-12 grid-col-sm-4 package--small" data-test="package--small">
# <h3 class="package__heading u-heading-8">labour leadership</h3>
# <div class="package__grid grid">
# <article class="card u-clickable-area grid-col grid-col-12 package-separator-bottom" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-5" data-track-wrapper="4-labour leadership">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/politics/2020/01/17/brexit-news-latest-big-ben-labour-leadership-boris-johnson/">
# <span class="list-headline__text">
# <span class="label-live u-separator-right--tight">
# <span class="label-live__icon">
# <span class="label-live__icon-inner"></span>
# </span>
# <span class="label-live__copy">Live</span>
# </span>
# Rebecca Long-Bailey vows to 'pick fight with establishment'
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/harry-yorke/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Harry Yorke" itemprop="name">Harry Yorke</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <article class="card u-clickable-area grid-col grid-col-12" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="4-labour leadership">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/women/politics/rebecca-long-baileys-toxic-views-abortion-matter-women/">
# <span class="list-headline__text">
# <span class="e-kicker u-separator-right--tight-inline">
# Comment
# </span>
# Long-Bailey's 'toxic' views on abortion matter for all women
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline e-byline--opinion" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a aria-label="Articles by Katherine O'Brien" class="e-byline__link" href="/authors/k/katherine-obrien/" rel="author">
# <span class="e-byline__author" content="Katherine O'Brien" itemprop="name">Katherine O'Brien</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# </div>
# </section>
# <section class="package grid-col grid-col-12 grid-col-sm-4 package--small" data-test="package--small">
# <h3 class="package__heading u-heading-8">Long reads</h3>
# <div class="package__grid grid">
# <article class="card u-clickable-area grid-col grid-col-8" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-5" data-track-wrapper="5-Long reads">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/news/0/life-metoo-inside-harvey-weinsteins-missing-two-years/">
# <span class="list-headline__text">
# <span class="e-kicker u-separator-right--tight-inline">
# Life after #MeToo
# </span>
# Inside Harvey Weinstein's missing two years
# </span>
# </a>
# </h3>
# <p class="e-standfirst e-standfirst--card" data-test="standfirst" itemprop="description">
# Mick Brown investigates the Hollywood impresario's low-profile life post #MeToo and talks to the lawyer protesting his innocence
# </p>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/mick-brown/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Mick Brown" itemprop="name">Mick Brown</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <div class="grid-col grid-col-4 package__image">
# <a href="/news/0/life-metoo-inside-harvey-weinsteins-missing-two-years/">
# <figure class="package__figure">
# <div class="lazy-image package__image-src" data-class="lazy-image__img" data-js="LazyImage" data-sizes="(min-width: 768px) 160px, 33.333vw" data-src="/content/dam/PortalPictures/January2020/170120_HARVEY-P.jpg" data-srcset="/content/dam/PortalPictures/January2020/170120_HARVEY-P.jpg?imwidth=160 160w, /content/dam/PortalPictures/January2020/170120_HARVEY-P.jpg?imwidth=210 210w, /content/dam/PortalPictures/January2020/170120_HARVEY-P.jpg?imwidth=320 320w, /content/dam/PortalPictures/January2020/170120_HARVEY-P.jpg?imwidth=350 350w, /content/dam/PortalPictures/January2020/170120_HARVEY-P.jpg?imwidth=480 480w, /content/dam/PortalPictures/January2020/170120_HARVEY-P.jpg?imwidth=640 640w" style="padding-top:160%;">
# <noscript>
# <img class="responsive lazy-image__img package__image-src" src="/content/dam/PortalPictures/January2020/170120_HARVEY-P.jpg"/>
# </noscript>
# </div>
# </figure>
# </a>
# </div>
# <article class="card u-clickable-area grid-col grid-col-12 package-separator-top" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="5-Long reads">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/family/parenting/vs-now-15-real-rites-passage-2020/">
# <span class="list-headline__text">
# <span class="e-kicker u-separator-right--tight-inline">
# Then vs now
# </span>
# The 15 real rites of passage in 2020
# </span>
# </a>
# </h3>
# </article>
# </div>
# </section>
# <section class="package grid-col grid-col-12 package--large" data-test="package--large">
# <h3 class="package__heading u-heading-8">The best of France</h3>
# <div class="package__grid grid">
# <article class="card u-clickable-area grid-col grid-col-12 grid-col-sm-4 package-separator-bottom" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline" data-track-wrapper="6-The best of France">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/travel/destinations/europe/france/articles/best-french-departments/">
# <span class="list-headline__text">
# The 20 most beautiful corners of France, according to our expert
# </span>
# </a>
# </h3>
# <div class="u-meta card__meta card__meta-stacked--xs">
# <div class="card__meta-wrapper">
# <span class="e-byline" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a class="e-byline__link" href="/authors/a/anthony-peregrine/" rel="author">
# <span class="e-byline__bytext">By</span>
# <span class="e-byline__author" content="Anthony Peregrine" itemprop="name">Anthony Peregrine</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </article>
# <div class="grid-col grid-col-12 grid-col-sm-8 grid-row-lg-3 package__image package__image--large">
# <a href="/travel/destinations/europe/france/articles/best-french-departments/">
# <figure class="package__figure">
# <div class="lazy-image package__image-src" data-class="lazy-image__img" data-js="LazyImage" data-sizes="(min-width: 768px) 640px, 100vw" data-src="/content/dam/PortalPictures/January2020/france1.PNG" data-srcset="/content/dam/PortalPictures/January2020/france1.PNG?imwidth=160 160w, /content/dam/PortalPictures/January2020/france1.PNG?imwidth=210 210w, /content/dam/PortalPictures/January2020/france1.PNG?imwidth=320 320w, /content/dam/PortalPictures/January2020/france1.PNG?imwidth=350 350w, /content/dam/PortalPictures/January2020/france1.PNG?imwidth=480 480w, /content/dam/PortalPictures/January2020/france1.PNG?imwidth=640 640w" style="padding-top:62.5%;">
# <noscript>
# <img class="responsive lazy-image__img package__image-src" src="/content/dam/PortalPictures/January2020/france1.PNG"/>
# </noscript>
# </div>
# </figure>
# </a>
# </div>
# <article class="card u-clickable-area grid-col grid-col-6 grid-col-sm-4 package-separator-top-right" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="6-The best of France">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/travel/destinations/europe/france/articles/french-food-best-in-the-world/">
# <span class="list-headline__text">
# French food is still the best in the world – here's why
# </span>
# </a>
# </h3>
# </article>
# <article class="card u-clickable-area grid-col grid-col-6 grid-col-sm-8 grid-col-lg-4 package-separator-top-right card--not-fullwidth" data-test="card">
# <span class="e-subscriber-label" data-test="subscriber-label">Premium</span>
# <h3 class="list-headline u-heading-7" data-track-wrapper="6-The best of France">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/travel/destinations/europe/france/articles/france-best-secret-attractions/">
# <span class="list-headline__text">
# <span class="e-kicker u-separator-right--tight-inline">
# Secret France
# </span>
# 20 of the best places to discover in 2020
# </span>
# </a>
# </h3>
# </article>
# </div>
# </section>
# </div>
# <div class="grid-col grid-col-12 grid-col-md-4 grid-col-end">
# <div class="opinion">
# <header class="opinion__header">
# <h2 class="opinion__header-heading u-heading-5">
# Opinion
# </h2>
# <h4 class="opinion__header-subheading">
# Exclusively for subscribers
# </h4>
# </header>
# <div class="opinion__content">
# <div class="opinion__list">
# <div class="opinion__list-content grid">
# <article class="opinion__card u-clickable-area opinion__card--fullwidth grid-col grid-col-12">
# <h3 class="list-headline list-headline--premium u-heading-6">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/politics/2020/01/17/boris-can-make-big-ben-brexit-bongs-giving-leavers-reasons-cheer/">
# <span class="list-headline__text">
# Boris can make up for Big Ben Brexit bongs by giving Leavers other reasons to cheer
# </span>
# </a>
# </h3>
# <a aria-label="Articles by Asa Bennett" class="card__link" href="/authors/asa-bennett/">
# <div class="lazy-image card__author-image" data-alt="Asa Bennett" data-class="lazy-image__img" data-js="LazyImage" data-src="/content/dam/Author%20photos/Asa_Bennett_2.png?impolicy=byline-author" style="padding-top:%;">
# <noscript>
# <img alt="Asa Bennett" class="responsive lazy-image__img card__author-image" src="/content/dam/Author%20photos/Asa_Bennett_2.png?impolicy=byline-author"/>
# </noscript>
# </div>
# </a>
# <span class="e-byline e-byline--opinion e-byline--premium" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a aria-label="Articles by Asa Bennett" class="e-byline__link" href="/authors/asa-bennett/" rel="author">
# <span class="e-byline__author" content="Asa Bennett" itemprop="name">Asa Bennett</span>
# </a>
# </span>
# </span>
# </article>
# <article class="opinion__card u-clickable-area opinion__card--fullwidth grid-col grid-col-12">
# <h3 class="list-headline list-headline--premium u-heading-6">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/football/2020/01/17/sir-alex-fergusons-success-built-not-bought-now-jurgen-klopp/">
# <span class="list-headline__text">
# Sir Alex Ferguson's success was built, not bought – now Jurgen Klopp is doing the same
# </span>
# </a>
# </h3>
# <a aria-label="Articles by Jamie Carragher" class="card__link" href="/authors/jamie-carragher/">
# <div class="lazy-image card__author-image" data-alt="Jamie Carragher" data-class="lazy-image__img" data-js="LazyImage" data-src="/content/dam/Author%20photos/Jamie_Carragher.png?impolicy=byline-author" style="padding-top:%;">
# <noscript>
# <img alt="Jamie Carragher" class="responsive lazy-image__img card__author-image" src="/content/dam/Author%20photos/Jamie_Carragher.png?impolicy=byline-author"/>
# </noscript>
# </div>
# </a>
# <span class="e-byline e-byline--opinion e-byline--premium" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a aria-label="Articles by Jamie Carragher" class="e-byline__link" href="/authors/jamie-carragher/" rel="author">
# <span class="e-byline__author" content="Jamie Carragher" itemprop="name">Jamie Carragher</span>
# </a>
# </span>
# </span>
# </article>
# <article class="opinion__card u-clickable-area opinion__card--fullwidth grid-col grid-col-12">
# <h3 class="list-headline list-headline--premium u-heading-6">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/business/2020/01/17/time-running-save-dying-stock-markets/">
# <span class="list-headline__text">
# Time is running out to save our dying stock markets
# </span>
# </a>
# </h3>
# <a aria-label="Articles by Jeremy Warner" class="card__link" href="/authors/jeremy-warner/">
# <div class="lazy-image card__author-image" data-alt="Jeremy Warner" data-class="lazy-image__img" data-js="LazyImage" data-src="/content/dam/Author%20photos/Jeremy%20Warner-S.png?impolicy=byline-author" style="padding-top:%;">
# <noscript>
# <img alt="Jeremy Warner" class="responsive lazy-image__img card__author-image" src="/content/dam/Author%20photos/Jeremy%20Warner-S.png?impolicy=byline-author"/>
# </noscript>
# </div>
# </a>
# <span class="e-byline e-byline--opinion e-byline--premium" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a aria-label="Articles by Jeremy Warner" class="e-byline__link" href="/authors/jeremy-warner/" rel="author">
# <span class="e-byline__author" content="Jeremy Warner" itemprop="name">Jeremy Warner</span>
# </a>
# </span>
# </span>
# </article>
# </div>
# </div>
# <div class="opinion__list">
# <div class="opinion__list-content grid">
# <article class="opinion__card u-clickable-area grid-col grid-col-6">
# <h3 class="list-headline list-headline--premium u-heading-7">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/politics/2020/01/16/farcical-row-eu-parliament-summed-brexit-happening/">
# <span class="list-headline__text">
# This farcical row in the EU Parliament summed up why Brexit is happening
# </span>
# </a>
# </h3>
# <span class="e-byline e-byline--opinion e-byline--premium" data-test="byline">
# <span class="e-byline__meta" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <a aria-label="Articles by Michael Deacon" class="e-byline__link" href="/authors/michael-deacon/" rel="author">
# <span class="e-byline__author" content="Michael Deacon" itemprop="name">Michael Deacon</span>
# </a>
# </span>
# </span>
# </article>
# <article class="opinion__card u-clickable-area grid-col grid-col-6">
# <h3 class="list-headline list-headline--premium u-heading-7">
# <a class="list-headline__link u-clickable-area__link" data-track-block="" href="/news/2020/01/17/beginning-end-vladimir-putin/">
# <span class="list-headline__text">
# This is the beginning of the end of Vladimir Putin
# </span>
# </a>
# </h3>
# ...
# </svg>
# </a>
# </div>
# <div class="site-header__utilities grid-col grid-col-end grid-col-sm-8 grid-col-md-7 grid-col-lg-8" data-track-wrapper="header-utilities">
# <article class="u-separator-left u-separator-left--pseudo u-clickable-area e-utility">
# <div class="e-utility__content u-order-late">
# <h4 class="e-utility__title u-heading-9">
# <a class="e-utility__link u-clickable-area__link" data-track-txt="" href="https://secure.telegraph.co.uk/secure/newsletter/technology-intelligence/?icid=Technology_Tech-Intelligence_text_portal_utility-bar">
# TECHNOLOGY INTELLIGENCE
# </a>
# </h4>
# <p class="e-utility__description">Your daily dose of the best tech news and analysis straight from Silicon Valley</p>
# </div>
# <div class="e-utility__image u-order-first">
# <div class="lazy-image" data-class="lazy-image__img" data-js="LazyImage" data-src="/content/dam/emailing/Editorialnewsletterthumbnails/utilities-technology_intelligence-uk-square-newsletter.png?impolicy=utilities-thumbnail" style="padding-top:100%;">
# <noscript>
# <img class="responsive lazy-image__img" src="/content/dam/emailing/Editorialnewsletterthumbnails/utilities-technology_intelligence-uk-square-newsletter.png?impolicy=utilities-thumbnail"/>
# </noscript>
# </div>
# </div>
# </article>
# <article class="u-separator-left u-separator-left--pseudo u-clickable-area e-utility">
# <div class="e-utility__content u-order-late">
# <h4 class="e-utility__title u-heading-9">
# <a class="e-utility__link u-clickable-area__link" data-track-txt="" href="https://www.telegraph.co.uk/brexit-podcast/">
# CHOPPER'S BREXIT PODCAST
# </a>
# </h4>
# <p class="e-utility__description">Join Christopher Hope for big interviews and the inside story on Brexit</p>
# </div>
# <div class="e-utility__image u-order-first">
# <div class="lazy-image" data-class="lazy-image__img" data-js="LazyImage" data-src="/content/dam/utility-bar/utilities-choppers-brexit-podcast-circle-podcast.png?impolicy=utilities-thumbnail" style="padding-top:100%;">
# <noscript>
# <img class="responsive lazy-image__img" src="/content/dam/utility-bar/utilities-choppers-brexit-podcast-circle-podcast.png?impolicy=utilities-thumbnail"/>
# </noscript>
# </div>
# </div>
# </article>
# <article class="u-separator-left u-separator-left--pseudo u-clickable-area e-utility e-utility--last">
# <div class="e-utility__content u-order-late">
# <h4 class="e-utility__title u-heading-9">
# <a class="e-utility__link u-clickable-area__link" data-track-txt="" href="https://www.telegraph.co.uk/rewards/?icid=subs-offers_rewards_nav-bar_generic_utilities_1019">
# SUBSCRIBER REWARDS
# </a>
# </h4>
# <p class="e-utility__description">Discover exciting offers, events and competitions exclusively for subscribers
# </p>
# </div>
# <div class="e-utility__image u-order-first">
# <div class="lazy-image" data-class="lazy-image__img" data-js="LazyImage" data-src="/content/dam/utility-bar/TEL_Rewards_utilities_circle.png?impolicy=utilities-thumbnail" style="padding-top:100%;">
# <noscript>
# <img class="responsive lazy-image__img" src="/content/dam/utility-bar/TEL_Rewards_utilities_circle.png?impolicy=utilities-thumbnail"/>
# </noscript>
# </div>
# </div>
# </article>
# </div>
# </div>
# <div class="site-header__primary-navigation-wrapper">
# <div class="site-header__navigation" data-drag-scroll="">
# <nav aria-label="Global website navigation" class="site-navigation" role="navigation">
# <ul class="site-navigation__list site-navigation__list--primary" data-track-wrapper="header-nav-primary">
# <li class="e-navigation-primary-item e-navigation-primary-item--first" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/news/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# News
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/politics/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Politics
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/sport/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Sport
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/business/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Business
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/money/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Money
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/opinion/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Opinion
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/technology/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Tech
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/lifestyle/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Life
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/style/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Style
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/travel/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Travel
# </span>
# </span>
# </a>
# </li>
# <li class="e-navigation-primary-item e-navigation-primary-item--last" data-accordion-max-screen-width="1024">
# <a class="e-navigation-primary-item__link" data-track-txt="" href="/culture/">
# <span class="e-navigation-primary-item__link-content">
# <span class="e-navigation-primary-item__link-text e-navigation-border">
# Culture
# </span>
# </span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="site-header__buttons">
# <div class="e-site-header-button e-site-header-button--search">
# <a aria-label="Search The Telegraph" class="e-site-header-button__link" href="https://www.telegraph.co.uk/search.html">
# <svg class="e-site-header-button__icon" viewbox="0 0 12 16" xmlns="http://www.w3.org/2000/svg">
# <title>Search Icon</title>
# <path d="M12,14.91l-3.24-5A5.5,5.5,0,1,0,5.5,11a5.27,5.27,0,0,0,1.44-.2L10.32,16ZM2,5.5A3.5,3.5,0,1,1,5.5,9,3.5,3.5,0,0,1,2,5.5Z"></path>
# </svg>
# </a>
# </div>
# <div class="e-site-header-button e-site-header-button--subscribe">
# <a class="e-site-header-button__link" data-icid="{ 'product': 'premiumsub', 'contentLocation': 'topnav' }" href="https://premium.telegraph.co.uk/">
# <span class="e-site-header-button__link-text-wrap">
# <span class="e-site-header-button__link-text e-site-header-button__link-text--message">
# Subscribe now
# </span>
# <span class="e-site-header-button__link-text e-site-header-button__link-text--description">
# Free for 30 days
# </span>
# </span>
# <svg class="e-site-header-button__arrow tmg-svg-icon" viewbox="0 0 10 5" xmlns="http://www.w3.org/2000/svg">
# <path d="M.312 0L5 2.353 9.687 0 10 .294 5 5 0 .294.312 0z"></path>
# </svg>
# </a>
# </div>
# <div class="e-site-header-button e-site-header-button--sign-in">
# <a class="e-site-header-button__link e-site-header-button__link--no-border" data-redirect-current="" href="/secure/login/">
# 									Log in
# 								</a>
# </div>
# <div class="e-site-header-button e-site-header-button--menu">
# <a aria-label="View all sections" class="e-site-header-button__link" data-modal-open-button="" href="/all-sections/">
# <span class="e-site-header-button__icon"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="container">
# <div class="snippet-footer">
# <section class="snippet-footer">
# <footer data-tmg-dtm-nav-area="footernav">
# <div class="footer-list-corporate component">
# <div class="component-content">
# <nav>
# <ul class="footer-list-corporate__list">
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="1-nav:/contact-us.html" href="/contact-us/">
# Contact us
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="2-nav:https://corporate.telegraph.co.uk/" href="https://corporate.telegraph.co.uk/">
# About us
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="3-nav:/rewards.html" href="/rewards/" title="Rewards">
# Rewards
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="4-nav:https://www.telegraph.co.uk/archive/" href="https://www.telegraph.co.uk/archive/">
# Archive
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="5-nav:http://telegraph.newsprints.co.uk/" href="http://telegraph.newsprints.co.uk/">
# Reader Prints
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="6-nav:/branded-content.html" href="/branded-content/">
# Branded Content
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="7-nav:/syndication.html" href="/syndication/" title="Syndication &amp; Content Partnerships">
# Syndication and Commissioning
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="8-nav:/about-us/editorial-and-commercial-guidelines.html" href="/about-us/editorial-and-commercial-guidelines/">
# Guidelines
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="9-nav:/about-us/privacy-and-cookie-policy.html" href="/about-us/privacy-and-cookie-policy/">
# Privacy
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="10-nav:/about-us/terms-and-conditions.html" href="/about-us/terms-and-conditions/">
# Terms and Conditions
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="11-nav:http://spark.telegraph.co.uk/toolkit/advertising/terms-and-conditions/" href="http://spark.telegraph.co.uk/toolkit/advertising/terms-and-conditions/">
# Advertising terms
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="12-nav:https://fantasyfootball.telegraph.co.uk" href="https://fantasyfootball.telegraph.co.uk">
# Fantasy Sport
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="13-nav:https://www.telegraph.co.uk/vouchercodes" href="https://www.telegraph.co.uk/vouchercodes">
# UK Voucher Codes
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="14-nav:/betting/free-bets.html" href="/betting/free-bets/" title="Betting Offers">
# Betting Offers
# </a>
# </li>
# <li class="footer-list-corporate__item">
# <a class="footer-list-corporate__link" data-tmg-dtm-nav="15-nav:/about-us/modern-slavery-statement.html" href="/about-us/modern-slavery-statement/">
# Modern Slavery
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="footer-copyright component">
# <div class="component-content">
# <p>© Telegraph Media Group Limited 2020</p>
# </div>
# </div>
# </footer>
# </section>
# </div>
# </div>
# <div class="spark-slot4">
# </div>
# <script type="text/javascript">
# 	window.addEventListener( 'DOMContentLoaded', function() {
# 		_satellite.pageBottom();
# 	});
# </script>
# <div class="adblocker-message component" style="display: none;">
# <div class="component-content">
# <div class="cartoon">
# <img alt="Please support us by disabling your adblocker" class="adblock-image" src="/content/dam/generic/Matt-cartoon-255x206px-small.png"/>
# </div>
# <div class="adblocker-message__body">
# <h3>We've noticed you're adblocking.</h3>
# <p>We rely on advertising to help fund our award-winning journalism.</p>
# <p>We urge you to turn off your ad blocker for The Telegraph website so that you can continue to access our quality content in the future.</p>
# <p>Thank you for your support.</p>
# </div>
# <p class="bold">Need help?</p>
# <p>Visit our <a class="help" href="https://www.telegraph.co.uk/go/adblocking/">adblocking instructions</a>
# page.</p>
# <div class="logo"></div>
# <button class="close" data-tmg-event="click" data-tmg-name="adBlockMessageClose">Close</button>
# </div>
# </div>
# <div class="js-advert advert" data-adtype="tmg" id="advert_tmg_tmg"></div>
# <div class="js-advert advert" data-adtype="ftr" id="advert_tmg_ftr"></div>
# </body>
# </html>

# %%
# Selects all the containers

container = soup.find('main')

# %%
articles = container.find_all('article')
len(articles)
# Out:
# 94

# %%
titles = [article.find('h3', class_="list-headline").text.strip() for article in articles]
len(titles)
# Out:
# 94

# %%
for title in titles:
    print(title)
    print('\n\n')
# Out:
# Exclusive
#
# MPs' £500,000 bill to sound 'Brexit bongs' is 35 times more than sounding Big Ben on New Year's Eve
#
#
#
# EU citizens will not be automatically deported after the Brexit grace period, says Guy Verhofstadt
#
#
#
# Saracens players told relegation inevitable after club accepts another deduction
#
#
#
# Football for sale
#
# Agents and manager sentenced over corruption scandal
#
#
#
# Meghan joined at her Canadian hideaway by 'little blonde guru' Pilates instructor
#
#
#
# Who is Heather Dorak, Meghan’s close friend and Pilates teacher?
#
#
#
# Live
#
#
# South Africa v England day two
#
# Live score and latest updates
#
#
#
# South Africa hit with massive blow as Rabada banned for final Test for wicket celebration
#
#
#
# Cricket always finds a way to shoot itself in the foot - the Kagiso Rabada ban for celebrating is ridiculous
#
#
#
# Why going 'full Monzo' can damage your credit score
#
#
#
# The British stock that returned more than Amazon in the last decade
#
#
#
# Live
#
# Rebecca Long-Bailey vows to 'pick fight with establishment'
#
#
#
# Comment
#
# Long-Bailey's 'toxic' views on abortion matter for all women
#
#
#
# Life after #MeToo
#
# Inside Harvey Weinstein's missing two years
#
#
#
# Then vs now
#
# The 15 real rites of passage in 2020
#
#
#
# The 20 most beautiful corners of France, according to our expert
#
#
#
# French food is still the best in the world – here's why
#
#
#
# Secret France
#
# 20 of the best places to discover in 2020
#
#
#
# Boris can make up for Big Ben Brexit bongs by giving Leavers other reasons to cheer
#
#
#
# Sir Alex Ferguson's success was built, not bought – now Jurgen Klopp is doing the same
#
#
#
# Time is running out to save our dying stock markets
#
#
#
# This farcical row in the EU Parliament summed up why Brexit is happening
#
#
#
# This is the beginning of the end of Vladimir Putin
#
#
#
# Boris Johnson needs my Brexit battle plan to triumph in trade talks with the EU
#
#
#
# One key ingredient is still missing for Premier Foods to have a winning recipe
#
#
#
# The rise of Rebecca Long-Bailey shows that Labour has learnt nothing
#
#
#
# Time to talk about weight
#
#
#
# Putin's constitutional sleight of hand has all the marks of a power grab
#
#
#
# Derek Fowlds, actor who found fame alongside Basil Brush and went on to co-star in ‘Yes, Minister’ and ‘Heartbeat’
#
#
#
# John Dancy, classicist and reform-minded headmaster who in 1968 admitted girls to Marlborough
#
#
#
# Question Time row
#
# Laurence Fox says accusing him of 'white male privilege' is racism in row over Meghan media coverage
#
#
#
# JRR Tolkien's son Christopher hailed as a 'titan' following his death aged 95
#
#
#
# Iran's supreme leader says Europe 'cannot be trusted' in rare Friday prayers address
#
#
#
# Hong Kong Express Airways says sorry after forcing passenger to take pregnancy test
#
#
#
# Live
#
# Investors brace for rate cut after ‘shockingly weak’ retail sales – live updates
#
#
#
# China's growth falls to its lowest in 30 years
#
#
#
# Banks crack down on lending over fears of a dangerous debt bubble
#
#
#
# Flybe hits out at 'inaccurate reporting' as war of words escalates
#
#
#
# United's new captain
#
# Maguire handed armband as Young moves to Inter Milan
#
#
#
# Fed Cup blow
#
# Johanna Konta rules herself out British team
#
#
#
# Yes, Minister
#
# Derek Fowld's Bernard was one of TV's great comic creations
#
#
#
# 'It's Iceland meets New Zealand' – exploring Europe's most epic archipelago
#
#
#
# Gwyneth Paltrow’s vagina-obsessed Goop Lab brings her ‘wellness’ brand to Netflix, and it’s not funny
#
#
#
# Pianist Igor Levit
#
# The racist who threatened to kill me in front of my audience
#
#
#
# I feel undervalued at work and was refused a pay rise. What should I do?
#
#
#
# I've found the perfect Greek island for a laid-back family holiday
#
#
#
# Katie Morley investigates
#
# ‘Virgin train was 102 minutes late but I never got any compensation’
#
#
#
# Inside a cutting-edge architect's unexpectedly cosy country cottage
#
#
#
# How 'death ray' laser weapons could lead to a new era in warfare
#
#
#
# Could we ever create an AI as smart as the human brain?
#
#
#
# 'This is what true happiness feels (and smells) like' – inside Borgo Egnazia's 'Happiness Retreat'
#
#
#
# Saracens relegation threat explained
#
# All the key questions answered as club faces expulsion
#
#
#
# Inside the fight for China's single women to be allowed to freeze their eggs
#
#
#
# The secrets of Westminster Abbey – an exclusive behind-the-scenes tour
#
#
#
# The best films to watch at the cinema this week – and what to avoid
#
#
#
# Hidden villages, spooky tunnels and clever monkeys: things you didn't know about Paris
#
#
#
# Concrete reinforced
#
# 6 ways to rock the industrial look that’s not going away
#
#
#
# The fashion editor's guide to activewear, for every shape and size
#
#
#
# How to create a three-course meal in 30 minutes
#
#
#
# The 9 best beauty products to buy now, according to The Telegraph's experts
#
#
#
# I'm proof that regular sex staves off the menopause - and so much more
#
#
#
# William Sitwell reviews Trivet, London
#
# ‘It was quite the most perfect dish of chicken I can imagine’
#
#
#
# The style lessons to learn from Gillian Anderson’s chic Sex Education style - and how to get the look
#
#
#
# 'My builder took me for a ride. Will his error stop me from selling my house?'
#
#
#
# Questor: ready for both fear and greed – why this ‘wealth preservation’ trust is a hold
#
#
#
# Get inspiration for your 2020 holidays with our in-depth guides
#
#
#
# Andrew English ranks the best automobiles of all time
#
#
#
# Browse our vast collection of recipes from the Telegraph's award-winning columnists
#
#
#
# Become a successful landlord with our expert guide and interactive tools
#
#
#
# After a road accident, I had to learn to walk again before I could take part in the London Marathon
#
#
#
# Meet the RAF cadets helping teens with disabilities 'take to the sky'
#
#
#
# Honest John: my BMW’s flaking wheels are not fit for purpose, what can I do?
#
#
#
# Lexus RX450h review: if there’s such a thing as an ideal urban SUV, this is it
#
#
#
# Yes, Minister: Derek Fowld’s Bernard was one of TV's great comic creations
#
#
#
# How we forgot Alice Guy-Blaché, cinema’s first female director
#
#
#
# Hotel Hit Squad: Great Scotland Yard isn’t as arresting as it should be for the price – except for Robin Gill's rustic, honest food
#
#
#
# 'I'm addicted': Bill Oddie on the lesser-known part of Portugal he keeps going back to
#
#
#
# Inside the fight for China's single women to be allowed to freeze their eggs
#
#
#
# Who is Heather Dorak, Meghan’s close friend and Pilates teacher?
#
#
#
# Poor knights of Windsor (French toast) recipe
#
#
#
# Spinach and parsley soda bread recipe
#
#
#
# What Meghan's 'Just Like Us' jumper tells us about her new style chapter
#
#
#
# Aeyde co-founder Luisa Dames on her best vintage treasures - and how ankle boots have changed her life
#
#
#
# The 9 best beauty products to buy now, according to The Telegraph's experts
#
#
#
# The Telegraph editors reveal their 2020 beauty resolutions
#
#
#
# Eminem, Music to be Murdered By, review: ‘so lethally brilliant it should be a crime’
#
#
#
# Mellowing Turnage meets chilly Britten in Philharmonia Orchestra's ode to the French horn, plus the best classical concerts of January 2020
#
#
#
# Six exceptional new women's watches from LVMH Watch Week
#
#
#
# The best Chinese restaurants in London to celebrate the Year of the Rat
#
#
#
# Inside the fight for China's single women to be allowed to freeze their eggs
#
#
#
# Who is Heather Dorak, Meghan’s close friend and Pilates teacher?
#
#
#
# The best TV streaming devices for watching Netflix, Amazon, and iPlayer
#
#
#
# How to raise an alpha kid: the super-rich parent's guide to acting
#
#
#
# The best men's walking boots
