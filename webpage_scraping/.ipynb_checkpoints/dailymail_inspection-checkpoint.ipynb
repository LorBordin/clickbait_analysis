# %%
# Daily Mail Url

import requests

URL = 'https://www.dailymail.co.uk/news/index.html'
page = requests.get(URL)

# %%
# Parse the content

from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "//www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html><head><!--class fe.views.page_modules.Head-->
# <!--class fe.views.head_modules.DefineAdvertsProperty-->
# <script type="text/javascript">
# try {
#   Object.defineProperty(window, 'adverts', {configurable: false, value:{}});
# }
# catch(error) {
#   console.error(error);
# }
# </script>
# <!--class fe.views.head_modules.Favicon-->
# <link href="/favicon.ico?v=2" rel="icon"/>
# <!--class fe.views.head_modules.Title-->
# <title>News Headlines | Today's UK &amp; World News | Daily Mail Online</title>
# <!--class fe.views.preload.Preload-->
# <link href="//swa.and.co.uk" rel="dns-prefetch"/>
# <link href="//i.dailymail.co.uk" rel="dns-prefetch"/>
# <link href="//video.dailymail.co.uk" rel="dns-prefetch"/>
# <link href="//scripts.dailymail.co.uk" rel="dns-prefetch"/>
# <link href="//ted.dailymail.co.uk" rel="dns-prefetch"/>
# ...

# %%
news_container = soup.find(id="page-container")   ## Contains all the news

# %%
all_articles = news_container.find_all('div', class_='article')
len(all_articles)
# Out:
# 116

# %%
first_article = all_articles[0]
first_article.find('h2', class_='linkro-darkred').text.strip()
# Out:
# 'Prince Harry manages a smile as he makes his first public appearance since Megxit at the Rugby League World Cup draw at Buckingham Palace - but will it be his last job as a senior member of the Royal Family?'

# %%
news_titles = []
for news in all_articles:
    title = news.find('h2', class_='linkro-darkred')
    news_titles.append(title.text.strip())
    print(title.text.strip())
    print()
# Out:
# Prince Harry manages a smile as he makes his first public appearance since Megxit at the Rugby League World Cup draw at Buckingham Palace - but will it be his last job as a senior member of the Royal Family?
#
# BA captain sends Mayday alert and wears oxygen mask to land plane at Heathrow as co-pilot is 'overcome by fumes' at controls
#
# Cat-loving psychotherapist wins £20,000 court battle to BAN her RHS Chelsea Flower Show-winning neighbour from feeding her free-roaming feline Ozzy
#
# Prince Andrew faces losing armed guard as Home Office recommends major downgrade of security after Jeffrey Epstein scandal
#
# THIRD storm in four days blasts Britain: Flood threat in 165 parts of UK as week's worth of rain and 60mph gusts strike - after week-long weather chaos forces Great Ouse to burst its banks and swamp St Ives
#
# Twice-married senior policeman, 49, faces court after 'having sex with an ex-Scottish Premiership footballer's wife, 41, in a car at a park and ride'
#
# ...

# %%
from pandas import Series

news_titles_ser = Series(news_titles)
news_titles_ser
# Out:
# 0      Prince Harry manages a smile as he makes his f...
# 1      BA captain sends Mayday alert and wears oxygen...
# 2      Cat-loving psychotherapist wins £20,000 court ...
# 3      Prince Andrew faces losing armed guard as Home...
# 4      THIRD storm in four days blasts Britain: Flood...
#                              ...
# 111    Are millennials killing off the fry-up? One in...
# 112    Tourists are told to avoid Alicante airport un...
# 113    Russia boxer Sergey Kovalev 'is sued by the wo...
# 114    Father who was exonerated in his wife's 1990 m...
# 115    REVEALED: Cause of the baffling death of an ot...
# Length: 116, dtype: object

# %%
news_titles_ser.to_csv()
